# %% [markdown]
# <a href="https://colab.research.google.com/github/Mili-cent/hello/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import math

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2c64dcc2-f445-4a01-a27e-88dfe5c48a4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c64dcc2-f445-4a01-a27e-88dfe5c48a4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving retiree-pensions-annual-benefit-received.csv to retiree-pensions-annual-benefit-received.csv
# ...

# %%
df = pd.read_csv(r"/content/office-of-the-comptroller-nyc-employee-retirement-system-nycers-holdings-data-1.csv")
print(df)
# Out:
#       CUSIP Number SEDOL Number Local Currency Code  \
# 0       '8611229F8            '                 USD
# 1       '8611229F8            '                 USD
# 2             'USD            '                 USD
# 3             'USD            '                 USD
# 4       '8611229F8            '                 USD
# ...            ...          ...                 ...
# 30359   '663642908     '6636421                 ZAR
# 30360   '658857909     '6588577                 ZAR
# 30361   '662271907     '6622710                 ZAR
# 30362   'B030GJ908     'B030GJ7                 ZAR
# 30363   'B038WK900     'B038WK4                 ZAR
#
#                    Trade Country Name                 Security Name  \
# 0      UNITED STATES OF AMERICA (THE)  STATE STREET BANK + TRUST CO
# 1      UNITED STATES OF AMERICA (THE)  STATE STREET BANK + TRUST CO
# 2      UNITED STATES OF AMERICA (THE)                     US DOLLAR
# ...

# %%
df["Interest Rate"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Original Face"].plot.hist()

# %%
df["Shares/Par Value"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Base Market Value"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Base Total Cost"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Base Unrealized Gain/Loss"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Base Accrued Interest"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Local Market Value"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Local Total Cost Amount"].plot.hist(bins= 20, figsize= (10,5))

# %%
df["Local Unrealized Gain/Loss"].plot.hist(bins= 20, figsize= (10,5))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30364 entries, 0 to 30363
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CUSIP Number                30364 non-null  object
#  1   SEDOL Number                30364 non-null  object
#  2   Local Currency Code         30364 non-null  object
#  3   Trade Country Name          30364 non-null  object
#  4   Security Name               30364 non-null  object
#  5   Security Description        30171 non-null  object
#  6   Maturity Date               9834 non-null   object
#  7   Interest Rate               30364 non-null  float64
#  8   Original Face               30363 non-null  float64
#  9   Shares/Par Value            30364 non-null  float64
#  10  Base Market Value           30364 non-null  float64
#  11  Base Total Cost             30364 non-null  float64
#  12  Base Unrealized Gain/Loss   30364 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# CUSIP Number                      0
# SEDOL Number                      0
# Local Currency Code               0
# Trade Country Name                0
# Security Name                     0
# Security Description            193
# Maturity Date                 20530
# Interest Rate                     0
# Original Face                     1
# Shares/Par Value                  0
# Base Market Value                 0
# Base Total Cost                   0
# Base Unrealized Gain/Loss         0
# Base Accrued Interest             0
# Local Market Value                0
# Local Total Cost Amount           0
# Local Unrealized Gain/Loss        0
# Local Accrued Interest            0
# Period End Date                   0
# Asset Class                       0
# Investment Type Name              0
# Major Industry Name               0
# Minor Industry Name               0
# Moody's Quality Rating        21455
# S and P Quality Rating        13833
# Direct/Group Trust Holding        0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.heatmap(df.isnull(), yticklabels = False,  cmap= "viridis")

# cloured evaluates to true for nan values

# %%
sns.boxplot(x= "Period End Date", y= "Base Market Value", data= df)

# %%
sns.boxplot(x= "Local Accrued Interest", y= "Base Market Value", data= df)

# %%
sns.boxplot(x= "Investment Type Name", y= "Base Market Value", data= df)

# %%
sns.boxplot(x= "Major Industry Name", y= "Base Market Value", data= df)

# %%
sns.boxplot(x= "Trade Country Name", y= "Base Market Value", data= df)

# %%
sns.boxplot(x= "Base Market Value", y= "Trade Country Name", data= df)

# %%
df.drop("Security Description", axis=1,inplace= True)

# %%
df.dropna(inplace= True)

# %%
df.drop("Maturity Date", axis=1,inplace= True)

# %%
df.dropna(inplace= True)

# %%
df.drop("Moody's Quality Rating", axis=1,inplace= True)

# %%
df.dropna(inplace= True)

# %%
df.drop("S and P Quality Rating",axis=1, inplace = True)

# %%
df.dropna(inplace= True)

# %%
df.isnull().sum()
# Out:
# CUSIP Number                  0
# SEDOL Number                  0
# Local Currency Code           0
# Trade Country Name            0
# Security Name                 0
# Interest Rate                 0
# Original Face                 0
# Shares/Par Value              0
# Base Market Value             0
# Base Total Cost               0
# Base Unrealized Gain/Loss     0
# Base Accrued Interest         0
# Local Market Value            0
# Local Total Cost Amount       0
# Local Unrealized Gain/Loss    0
# Local Accrued Interest        0
# Period End Date               0
# Asset Class                   0
# Investment Type Name          0
# Major Industry Name           0
# Minor Industry Name           0
# Direct/Group Trust Holding    0
# dtype: int64

# %%
df.head(20)
# Out:
#    CUSIP Number SEDOL Number  ... Minor Industry Name Direct/Group Trust Holding
# 21   '00790XAA9     'BZ1JMF9  ...          INDUSTRIAL                     Direct
# 22   '00165CAA2     'BYN5KH6  ...          INDUSTRIAL                     Direct
# 23   '513272AB0     'BYTY5N8  ...          INDUSTRIAL                     Direct
# 25   '497864AA6     'BYNMHG5  ...            CANADIAN                     Direct
# 26   '63530QAH2     'BYXVPM4  ...          INDUSTRIAL                     Direct
# 27   '87952VAL0     'BD83HB1  ...            CANADIAN                     Direct
# 28   '097751BP5     'BYZN7N3  ...            CANADIAN                     Direct
# 29   '853254BA7     'BDCXG98  ...        OTHER YANKEE                     Direct
# 30   '626717AH5     'BZBZ912  ...        ELECTRIC/GAS                     Direct
# 31   '670001AA4     'BD3BNM3  ...          INDUSTRIAL                     Direct
# 32   '978097AD5     'BDHBWC2  ...          INDUSTRIAL                     Direct
# ...

# %%
Investment_Type_Name= pd.get_dummies(df['Investment Type Name'], drop_first=True)
Investment_Type_Name.head(5)
# Out:
#     BANK LOAN  CMO  CONVERTIBLE BONDS  CORPORATE BONDS  CREDIT CARD RCVEABLE  \
# 21          0    0                  0                1                     0
# 22          0    0                  0                1                     0
# 23          0    0                  0                1                     0
# 25          0    0                  0                1                     0
# 26          0    0                  0                1                     0
#
#     FHLMC  FNMA  GNMA I  GNMA II  GOVERNMENT ISSUES  MUNICIPALS  \
# 21      0     0       0        0                  0           0
# 22      0     0       0        0                  0           0
# 23      0     0       0        0                  0           0
# 25      0     0       0        0                  0           0
# 26      0     0       0        0                  0           0
#
#     OTHER ASSET BACKED  STIF-TYPE INSTRUMENT
# 21                   0                     0
# ...

# %%
Asset_Class= pd.get_dummies(df['Asset Class'])
Asset_Class.head(5)
# Out:
#     CASH EQUIVALENT  FIXED INCOME
# 21                0             1
# 22                0             1
# 23                0             1
# 25                0             1
# 26                0             1

# %%
Local_Currency_Code= pd.get_dummies(df['Local Currency Code'])
Local_Currency_Code.head(5)
# Out:
#     EUR  GBP  NOK  USD  ZAR
# 21    0    0    0    1    0
# 22    0    0    0    1    0
# 23    0    0    0    1    0
# 25    0    0    0    1    0
# 26    0    0    0    1    0

# %%
Major_Industry_Name= pd.get_dummies(df['Major Industry Name'])
Major_Industry_Name.head(5)
# Out:
#     AGENCY  ASSET BACKED  BANK LOAN  CASH EQUIVALENT  CMO  CONVERTIBLES  \
# 21       0             0          0                0    0             0
# 22       0             0          0                0    0             0
# 23       0             0          0                0    0             0
# 25       0             0          0                0    0             0
# 26       0             0          0                0    0             0
#
#     CORPORATE  FOREIGN  INDUSTRIALS  MORTGAGE PASS-THROUGH  MUNICIPAL  \
# 21          1        0            0                      0          0
# 22          1        0            0                      0          0
# 23          1        0            0                      0          0
# 25          0        0            0                      0          0
# 26          1        0            0                      0          0
#
#     PRIVATE PLACEMENT  US TREASURY  YANKEE
# 21                  0            0       0
# ...

# %%
Trade_Country_Name= pd.get_dummies(df['Trade Country Name'])
Trade_Country_Name.head(5)
# Out:
#     AUSTRALIA  AUSTRIA  BELGIUM  BERMUDA  CANADA  CAYMAN ISLANDS (THE)  \
# 21          0        0        0        0       0                     0
# 22          0        0        0        0       0                     0
# 23          0        0        0        0       0                     0
# 25          0        0        0        0       0                     0
# 26          0        0        0        0       0                     0
#
#     FRANCE  GERMANY  HONG KONG  INTERNATIONAL  IRELAND  LUXEMBOURG  \
# 21       0        0          0              0        0           0
# 22       0        0          0              0        0           0
# 23       0        0          0              0        0           0
# 25       0        0          0              0        0           0
# 26       0        0          0              0        0           0
#
#     MARSHALL ISLANDS (THE)  NETHERLANDS (THE)  NORWAY  PORTUGAL  SPAIN  \
# ...

# %%
df= pd.concat([df,Investment_Type_Name,Asset_Class,Local_Currency_Code,Major_Industry_Name,Trade_Country_Name],axis=1)
df.head()
# Out:
#    CUSIP Number SEDOL Number Local Currency Code  \
# 21   '00790XAA9     'BZ1JMF9                 USD
# 22   '00165CAA2     'BYN5KH6                 USD
# 23   '513272AB0     'BYTY5N8                 USD
# 25   '497864AA6     'BYNMHG5                 USD
# 26   '63530QAH2     'BYXVPM4                 USD
#
#                 Trade Country Name             Security Name  Interest Rate  \
# 21  UNITED STATES OF AMERICA (THE)  ADVANCED DISPOSAL SRVCES          5.625
# 22  UNITED STATES OF AMERICA (THE)  AMC ENTERTAINMENT HOLDIN          5.875
# 23  UNITED STATES OF AMERICA (THE)           LAMB WESTON HLD          4.875
# 25  UNITED STATES OF AMERICA (THE)  KISSNER HLD / MILL / BSC          8.375
# 26  UNITED STATES OF AMERICA (THE)    NATIONAL CINEMEDIA LLC          5.750
#
#     Original Face  Shares/Par Value  Base Market Value  Base Total Cost  ...  \
# 21            0.0          375000.0          386250.00        375000.00  ...
# ...

# %%
df.drop(['Investment Type Name', 'Asset Class','Local Currency Code','Major Industry Name', 'Trade Country Name'],axis=1,inplace = True)

# %%
df.head()
# Out:
#    CUSIP Number SEDOL Number             Security Name  Interest Rate  \
# 21   '00790XAA9     'BZ1JMF9  ADVANCED DISPOSAL SRVCES          5.625
# 22   '00165CAA2     'BYN5KH6  AMC ENTERTAINMENT HOLDIN          5.875
# 23   '513272AB0     'BYTY5N8           LAMB WESTON HLD          4.875
# 25   '497864AA6     'BYNMHG5  KISSNER HLD / MILL / BSC          8.375
# 26   '63530QAH2     'BYXVPM4    NATIONAL CINEMEDIA LLC          5.750
#
#     Original Face  Shares/Par Value  Base Market Value  Base Total Cost  \
# 21            0.0          375000.0          386250.00        375000.00
# 22            0.0          495000.0          516656.25        497175.00
# 23            0.0         1055000.0         1093243.75       1051675.00
# 25            0.0         1730000.0         1794875.00       1774843.75
# 26            0.0         1005000.0          974850.00       1015237.50
#
#     Base Unrealized Gain/Loss  Base Accrued Interest  ...  IRELAND  \
# ...

# %%
##SPLITING THE DATASET

# %%
x=df.drop("FIXED INCOME", axis=1)

# %%
y=df["FIXED INCOME"]

# %%
pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split>

# %%
df2= df

# %%
df2.head()
# Out:
#     Interest Rate  Original Face  Shares/Par Value  Base Market Value  \
# 21          5.625            0.0          375000.0          386250.00
# 22          5.875            0.0          495000.0          516656.25
# 23          4.875            0.0         1055000.0         1093243.75
# 25          8.375            0.0         1730000.0         1794875.00
# 26          5.750            0.0         1005000.0          974850.00
#
#     Base Total Cost  Base Unrealized Gain/Loss  Base Accrued Interest  \
# 21        375000.00                   11250.00                2695.31
# 22        497175.00                   19481.25                3715.94
# 23       1051675.00                   41568.75                8571.88
# 25       1774843.75                   20031.25               12073.97
# 26       1015237.50                  -40387.50               21830.83
#
#     Local Market Value  Local Total Cost Amount  Local Unrealized Gain/Loss  \
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel= LogisticRegression()

# %%
df.head()
# Out:
#    CUSIP Number SEDOL Number             Security Name  Interest Rate  \
# 21   '00790XAA9     'BZ1JMF9  ADVANCED DISPOSAL SRVCES          5.625
# 22   '00165CAA2     'BYN5KH6  AMC ENTERTAINMENT HOLDIN          5.875
# 23   '513272AB0     'BYTY5N8           LAMB WESTON HLD          4.875
# 25   '497864AA6     'BYNMHG5  KISSNER HLD / MILL / BSC          8.375
# 26   '63530QAH2     'BYXVPM4    NATIONAL CINEMEDIA LLC          5.750
#
#     Original Face  Shares/Par Value  Base Market Value  Base Total Cost  \
# 21            0.0          375000.0          386250.00        375000.00
# 22            0.0          495000.0          516656.25        497175.00
# 23            0.0         1055000.0         1093243.75       1051675.00
# 25            0.0         1730000.0         1794875.00       1774843.75
# 26            0.0         1005000.0          974850.00       1015237.50
#
#     Base Unrealized Gain/Loss  Base Accrued Interest  ...  IRELAND  \
# ...

# %%
df.drop('CUSIP Number',axis=1,inplace=True)

# %%
df.drop('SEDOL Number',axis=1,inplace=True)

# %%
df.drop('Security Name',axis=1,inplace=True)

# %%
df.drop('Minor Industry Name',axis=1,inplace=True)

# %%
df.drop('Direct/Group Trust Holding',axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     Interest Rate  Original Face  Shares/Par Value  Base Market Value  \
# 21          5.625            0.0          375000.0          386250.00
# 22          5.875            0.0          495000.0          516656.25
# 23          4.875            0.0         1055000.0         1093243.75
# 25          8.375            0.0         1730000.0         1794875.00
# 26          5.750            0.0         1005000.0          974850.00
# 27          8.875            0.0          440000.0          493900.00
# 28          8.750            0.0         2105000.0         2336550.00
# 29          7.500            0.0          975000.0         1043250.00
# 30          6.875            0.0          510000.0          532950.00
# 31          6.250            0.0         1155000.0         1212750.00
# 32          5.000            0.0          990000.0          976387.50
# 33          5.500            0.0         2030000.0         2055375.00
# ...

# %%
df = df.replace([' 25272KAW3'], '1')

# %%
logmodel=LogisticRegression()

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=1)

# %%
X_train = df.iloc[:,4:9]

# %%
df.head()
# Out:
#     Interest Rate  ...  UNITED STATES OF AMERICA (THE)
# 21          5.625  ...                               1
# 22          5.875  ...                               1
# 23          4.875  ...                               1
# 25          8.375  ...                               1
# 26          5.750  ...                               1
#
# [5 rows x 65 columns]

# %%
df2.dropna(inplace= True)

# %%
logmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1ce89131d408> in <module>()
#       1
# ----> 2 logmodel.fit(x_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6581 entries, 21 to 20469
# Data columns (total 66 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Interest Rate                   6581 non-null   float64
#  1   Original Face                   6581 non-null   float64
#  2   Shares/Par Value                6581 non-null   float64
#  3   Base Market Value               6581 non-null   float64
#  4   Base Total Cost                 6581 non-null   float64
#  5   Base Unrealized Gain/Loss       6581 non-null   float64
#  6   Base Accrued Interest           6581 non-null   float64
#  7   Local Market Value              6581 non-null   float64
#  8   Local Total Cost Amount         6581 non-null   float64
#  9   Local Unrealized Gain/Loss      6581 non-null   float64
#  10  Local Accrued Interest          6581 non-null   float64
#  11  Period End Date                 6581 non-null   object
# ...

# %%
df.drop('Local Accrued Interest',axis=1,inplace=True)

# %%
df.head()
# Out:
#     Interest Rate  ...  UNITED STATES OF AMERICA (THE)
# 21          5.625  ...                               1
# 22          5.875  ...                               1
# 23          4.875  ...                               1
# 25          8.375  ...                               1
# 26          5.750  ...                               1
#
# [5 rows x 65 columns]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-33aecbcba964> in <module>()
# ----> 1 logmodel.fit(x_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
predictions= logmodel.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-20e4f623f750> in <module>()
# ----> 1 predictions= logmodel.predict(x_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
vectorizer = TfidfVectorizer()
x_train_vec = vectorizer.fit_transform(x_train)

# %%
model = LogisticRegression(solver='liblinear', penalty='l1')

# %%
model.fit(x_train_vec, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-5f3b65c9fe10> in <module>()
# ----> 1 model.fit(x_train_vec, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
x.shape
# Out:
# (6581, 70)

# %%
y.shape
# Out:
# (6581,)

# %%
x = x.transpose()

# %%
x.shape
# Out:
# (6581, 70)

# %%
y.shape
# Out:
# (6581,)

# %%
logmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-33aecbcba964> in <module>()
# ----> 1 logmodel.fit(x_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
if 'CUSIP Number' in df2.columns:
    del df2['CUSIP Number']

# %%
logmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-33aecbcba964> in <module>()
# ----> 1 logmodel.fit(x_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
df = df.drop(['col1'], axis=1, errors='ignore')

# %%
logmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-33aecbcba964> in <module>()
# ----> 1 logmodel.fit(x_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
df.loc[:, '37045XBG0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# ...
